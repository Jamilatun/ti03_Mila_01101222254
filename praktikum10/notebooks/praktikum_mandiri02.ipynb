# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %% [markdown]
# **membuat dataset**

# %%
data = {
    "NIM": ["TI001","TI002","TI003","TI004","TI005","TI006","TI007","TI008","TI009","TI010"],
    "Actual": ["Lulus","Lulus","Lulus","Lulus","Lulus",
               "Tidak Lulus","Tidak Lulus","Tidak Lulus","Tidak Lulus","Tidak Lulus"],
    "Predicted": ["Lulus","Lulus","Tidak Lulus","Tidak Lulus","Lulus",
                  "Lulus","Tidak Lulus","Tidak Lulus","Lulus","Tidak Lulus"]
}

df = pd.DataFrame(data)
df
# Out:
#      NIM       Actual    Predicted
# 0  TI001        Lulus        Lulus
# 1  TI002        Lulus        Lulus
# 2  TI003        Lulus  Tidak Lulus
# 3  TI004        Lulus  Tidak Lulus
# 4  TI005        Lulus        Lulus
# 5  TI006  Tidak Lulus        Lulus
# 6  TI007  Tidak Lulus  Tidak Lulus
# 7  TI008  Tidak Lulus  Tidak Lulus
# 8  TI009  Tidak Lulus        Lulus
# 9  TI010  Tidak Lulus  Tidak Lulus

# %%
df['Actual'] = df['Actual'].replace({"Lulus":1, "Tidak Lulus":0})
df['Predicted'] = df['Predicted'].replace({"Lulus":1, "Tidak Lulus":0})

df
# Out:
#      NIM  Actual  Predicted
# 0  TI001       1          1
# 1  TI002       1          1
# 2  TI003       1          0
# 3  TI004       1          0
# 4  TI005       1          1
# 5  TI006       0          1
# 6  TI007       0          0
# 7  TI008       0          0
# 8  TI009       0          1
# 9  TI010       0          0

# %%
y_true = df['Actual']
y_pred = df['Predicted']

cm = confusion_matrix(y_true, y_pred)
cm
# Out:
# array([[3, 2],
#        [2, 3]])

# %%
cm_manual = [[3, 2],
             [2, 3]]
cm_manual
# Out:
# [[3, 2], [2, 3]]

# %%
acc = accuracy_score(y_true, y_pred)
prec = precision_score(y_true, y_pred)
rec = recall_score(y_true, y_pred)

print("Accuracy :", acc)
print("Precision:", prec)
print("Recall   :", rec)
# Out:
# Accuracy : 0.6
# Precision: 0.6
# Recall   : 0.6
